# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Shaikh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
for item in stop_words:
    print(item)
# Out:
# mustn
# and
# should've
# by
# where
# under
# there
# why
# aren't
# needn
# weren't
# through
# o
# myself
# are
# didn
# ve
# y
# own
# those
# were
# after
# as
# t
# any
# its
# was
# ll
# haven't
# for
# won
# itself
# because
# be
# yourself
# each
# it
# when
# my
# has
# should
# had
# wouldn't
# theirs
# is
# doing
# doesn't
# so
# wasn't
# this
# her
# shouldn
# only
# an
# same
# before
# didn't
# needn't
# me
# isn
# very
# won't
# hadn
# hadn't
# shouldn't
# about
# once
# them
# more
# further
# having
# if
# d
# during
# than
# all
# these
# him
# it's
# don
# can
# haven
# above
# you
# hasn
# up
# couldn't
# other
# she
# she's
# does
# doesn
# do
# your
# out
# s
# off
# mightn
# m
# ours
# shan't
# hers
# such
# mustn't
# we
# while
# but
# our
# whom
# over
# too
# below
# will
# i
# his
# you're
# just
# themselves
# ourselves
# a
# until
# against
# that
# with
# most
# herself
# which
# the
# into
# of
# now
# shan
# weren
# couldn
# their
# you'd
# again
# aren
# at
# you'll
# from
# on
# he
# few
# that'll
# both
# been
# you've
# they
# or
# to
# who
# yours
# hasn't
# himself
# here
# in
# have
# yourselves
# not
# re
# am
# nor
# wouldn
# how
# don't
# what
# being
# between
# ain
# wasn
# mightn't
# ma
# some
# then
# isn't
# did
# down
# no

# %%
tokenized_sent = ['My', 'favourite', 'colors', 'are', 'Red', ',', 'Blue', 'and', 'Purple', '.']
for w in tokenized_sent:
    print(w)
    if w not in stop_words:
        pass # Do something.
# Out:
# My
# favourite
# colors
# are
# Red
# ,
# Blue
# and
# Purple
# .
